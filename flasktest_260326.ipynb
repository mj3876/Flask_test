# %% [markdown]
# <a href="https://colab.research.google.com/github/mj3876/Flask_test/blob/main/flasktest_260326.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#netsted func중첩함수
def outer_function():
    print('call outer_func function')
    def inner_function():
        return 'call inner_func function'
    print(inner_function())
def outer_func(num):
    def inner_func():
        print(num)
        return 'complex'#이문자열과
    return inner_func
fn=outer_func(10)#이 값까지 리턴
print(fn())
# Out:
# 10
# complex

# %%
def logger(mag):
    message=mag
    def mag_creator():
        print('{HIGH LEVEL}', message)
    return mag_creator
log1=logger('me log in')
print(log1)
log1()#->내부함수가 안사라지고 출력됨
def html_creator(tag):
    def text_wrapper(msg):
        print('<{0}>{1}</{0}>'.format(tag,msg))
    return text_wrapper
h1_html_creator=html_creator('h1')
print(h1_html_creator)
h1_html_creator('H1태그는 타이틀을 표시하는 태그입니다')

def list_creator(tag):
    def text_wrapper(msg):
        print('{0} {1}'.format(tag,msg))
    return text_wrapper
data_list_minus=list_creator('-')
data_list_minus('안녕')
data_list_minus=list_creator('*')
data_list_minus('안녕')
data_list_minus=list_creator('+')
data_list_minus('안녕')
# Out:
# <function logger.<locals>.mag_creator at 0x7a66a07220c0>
# {HIGH LEVEL} me log in
# <function html_creator.<locals>.text_wrapper at 0x7a66a07228e0>
# <h1>H1태그는 타이틀을 표시하는 태그입니다</h1>
# - 안녕
# * 안녕
# + 안녕

# %%
import requests
from bs4 import BeautifulSoup
res =requests.get('https://davelee-fun.github.io/blog/crawl_html_css.html')
soup=BeautifulSoup(res.content,'html.parser')
link_titles=soup.select("ul#hobby_course_list > li")
def list_creator(tag):
    def text_wrapper(msg):
        print('{0} {1}'.format(tag,msg))
    return text_wrapper
data_list_minus=list_creator('-')
for link_title in link_titles:
    data_list_minus(link_title.get_text())
# Out:
# - (왕초보) - 클래스 소개
# - (왕초보) - 블로그 개발 필요한 준비물 준비하기
# - (왕초보) - Github pages 설정해서 블로그 첫 페이지 만들어보기
# - (왕초보) - 초간단 페이지 만들어보기
# - (왕초보) - 이쁘게 테마 적용해보기
# - (왕초보) - 마크다운 기초 이해하고, 실제 나만의 블로그 페이지 만들기
# - (왕초보) - 다양한 마크다운 기법 익혀보며, 나만의 블로그 페이지 꾸며보기
